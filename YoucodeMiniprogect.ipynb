# %% [markdown]
# # Partie1

# %%
import pandas as pd
data=pd.read_excel('data-sell4all.xlsx')
data.to_csv('data-sell4all.csv')
data
# Out:
#                  Pays           Age         Genre Dépenses des clients
# 0              France             32       Female               150.50
# 1             Germany             45         Male               200.75
# 2               Spain             28       Female                75.25
# 3               Italy             39         Male               180.00
# 4                  UK             52       Female               250.30
# ..                ...            ...          ...                  ...
# 60      Digital Realm            NaN           AI           1010101.01
# 61         Multiverse              ∞   Non-Binary                    π
# 62              Error            NaN          404                  NaN
# 63      Greece, Italy          25;30  Male;Female              100+200
# 64   United  Kingdom   Not Available        Other            Priceless
#
# [65 rows x 4 columns]

# %%
#explorer les données disponibles
print(data.info())
print(data.describe())
print(data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Pays                  65 non-null     object
#  1    Age                  62 non-null     object
#  2   Genre                 64 non-null     object
#  3   Dépenses des clients  63 non-null     object
# dtypes: object(4)
# memory usage: 2.2+ KB
# None
#           Pays   Age    Genre Dépenses des clients
# count       65     62      64                   63
# unique      20     40      12                   59
# top     France     28  Female               195.25
# freq        10      3      27                    2
# Index(['Pays', ' Age ', 'Genre', 'Dépenses des clients'], dtype='object')

# %% [markdown]
# ### Nettoyage

# %%
#nettoyage
data.columns = data.columns.str.strip()
print(data.columns)
# Out:
# Index(['Pays', 'Age', 'Genre', 'Dépenses des clients'], dtype='object')

# %%
data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

data['Age'] = pd.to_numeric(data['Age'], errors='coerce')
data['Dépenses des clients'] = pd.to_numeric(data['Dépenses des clients'], errors='coerce')

data = data.dropna()

data = data[data['Age'] >= 0]
data['Dépenses des clients'] = data['Dépenses des clients'].apply(lambda x: np.nan if isinstance(x, str) and not x.replace('.', '', 1).isdigit() else x)
data = data.dropna()
print(data)
# Out:
#          Pays     Age      Genre  Dépenses des clients
# 0      France    32.0     Female                150.50
# 1     Germany    45.0       Male                200.75
# 2       Spain    28.0     Female                 75.25
# 3       Italy    39.0       Male                180.00
# 4          UK    52.0     Female                250.30
# 5      France    22.0       Male                 90.00
# 6     Germany    36.0     Female                175.50
# 7       Spain    41.0       Male                120.75
# 8       Italy    29.0     Female                 95.25
# 9          UK    48.0       Male                220.00
# 10     France    35.0     Female                160.25
# 11    Germany    27.0       Male                 85.50
# 12      Spain    50.0     Female                190.75
# 13      Italy    33.0       Male                140.00
# 14         UK    44.0     Female                210.50
# 15     France    31.0       Male                130.25
# 16    Germany    38.0     Female                170.00
# 17      Spain    26.0       Male                  5.75
# 18      Italy    47.0     Female                200.25
# 19         UK    30.0       Male                110.50
# 21    Germany    29.0       Male                100.25
# 22      Spain    55.0     Female                230.00
# 23      Italy    36.0       Male                150.75
# 24         UK    25.0     Female                 80.50
# 25     France    49.0       Male                215.25
# 26    Germany    34.0     Female                145.00
# 27      Spain    40.0       Male                175.50
# 28      Italy    23.0     Female                 70.25
# 29         UK    51.0       Male                240.75
# 30     France    37.0     Female                165.00
# 31    Germany    43.0       Male                195.25
# 32      Spain    28.0     Female                 85.75
# 33      Italy    46.0       Male                205.50
# 34         UK    33.0     Female                135.25
# 35     France    30.0       Male                120.00
# 36    Germany    52.0     Female                225.75
# 37      Spain    35.0       Male                155.50
# 38      Italy    27.0     Female                 90.25
# 39         UK    48.0       Male                210.00
# 40     France    39.0     Female                170.25
# 41    Germany    31.0       Male                125.75
# 42      Spain    44.0     Female                190.00
# 43      Italy    25.0       Male                 75.50
# 44         UK    50.0     Female                220.25
# 46    Germany    41.0     Female                185.00
# 47      Spain    29.0       Male                105.25
# 48      Italy    53.0     Female                235.50
# 49         UK    32.0       Male                140.25
# 50        USA    28.0     Female                180.00
# 52  Australia    39.0     Female                210.50
# 53      Japan    33.0       Male                145.75
# 54     Brazil    47.0     Female                195.25
# 56       Moon   150.0      Lunar                  0.01
# 57   Atlantis  1000.0  Merperson                500.00

# %%
#affiche les 5 premières lignes du fichier CSV
data.head()
# Out:
#       Pays   Age   Genre  Dépenses des clients
# 0   France  32.0  Female                150.50
# 1  Germany  45.0    Male                200.75
# 2    Spain  28.0  Female                 75.25
# 3    Italy  39.0    Male                180.00
# 4       UK  52.0  Female                250.30

# %%
#nombre de lignes
data.shape[0]
# Out:
# 54

# %% [markdown]
# data.shape[0] donne le nombre de lignes dans le DataFrame, qui est 54 dans ce cas apres le nettoyage. Cela indique qu'il y a 54 enregistrements ou observations dans le fichier CSV.

# %%
#les colonnes du fichier CSV
data.columns.tolist()
# Out:
# ['Pays', 'Age', 'Genre', 'Dépenses des clients']

# %% [markdown]
# La fonction data.columns.tolist() retourne une liste des noms des colonnes du DataFrame, qui sont de ce cas Pays, Age, Genre et Dépenses des clients

# %%
#les types de données des champs du fichier CSV
data.dtypes
# Out:
# Pays                     object
# Age                     float64
# Genre                    object
# Dépenses des clients    float64
# dtype: object

# %% [markdown]
# la method data.dtype donne les types de donnes des differents champs existe dans la DataFrame

# %%
median_age = data['Age'].median()
mean_age = data['Age'].mean()

median_depenses = data['Dépenses des clients'].median()
mean_depenses = data['Dépenses des clients'].mean()

print(median_age)
print(mean_age)
print(median_depenses)
print(mean_depenses)
# Out:
# 36.5
# 57.31481481481482
# 162.625
# 159.95944444444447

# %% [markdown]
# # Partie2

# %%
import matplotlib.pyplot as plt

pays = data['Pays']
depenses = data['Dépenses des clients']

plt.figure(figsize=(10, 5))
plt.bar(pays, depenses, color='black')
plt.xlabel('Pays')
plt.ylabel('Dépenses des clients')
plt.title('Dépenses des clients par pays')
plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %%
#supprimez toutes les lignes d’utilisateurs ayant dépensé moins de 10 € sur le site,
data_filtered = data[data['Dépenses des clients'] >= 10]
data_filtered
# Out:
#          Pays     Age      Genre  Dépenses des clients
# 0      France    32.0     Female                150.50
# 1     Germany    45.0       Male                200.75
# 2       Spain    28.0     Female                 75.25
# 3       Italy    39.0       Male                180.00
# 4          UK    52.0     Female                250.30
# 5      France    22.0       Male                 90.00
# 6     Germany    36.0     Female                175.50
# 7       Spain    41.0       Male                120.75
# 8       Italy    29.0     Female                 95.25
# 9          UK    48.0       Male                220.00
# 10     France    35.0     Female                160.25
# 11    Germany    27.0       Male                 85.50
# 12      Spain    50.0     Female                190.75
# 13      Italy    33.0       Male                140.00
# 14         UK    44.0     Female                210.50
# 15     France    31.0       Male                130.25
# 16    Germany    38.0     Female                170.00
# 18      Italy    47.0     Female                200.25
# 19         UK    30.0       Male                110.50
# 21    Germany    29.0       Male                100.25
# 22      Spain    55.0     Female                230.00
# 23      Italy    36.0       Male                150.75
# 24         UK    25.0     Female                 80.50
# 25     France    49.0       Male                215.25
# 26    Germany    34.0     Female                145.00
# 27      Spain    40.0       Male                175.50
# 28      Italy    23.0     Female                 70.25
# 29         UK    51.0       Male                240.75
# 30     France    37.0     Female                165.00
# 31    Germany    43.0       Male                195.25
# 32      Spain    28.0     Female                 85.75
# 33      Italy    46.0       Male                205.50
# 34         UK    33.0     Female                135.25
# 35     France    30.0       Male                120.00
# 36    Germany    52.0     Female                225.75
# 37      Spain    35.0       Male                155.50
# 38      Italy    27.0     Female                 90.25
# 39         UK    48.0       Male                210.00
# 40     France    39.0     Female                170.25
# 41    Germany    31.0       Male                125.75
# 42      Spain    44.0     Female                190.00
# 43      Italy    25.0       Male                 75.50
# 44         UK    50.0     Female                220.25
# 46    Germany    41.0     Female                185.00
# 47      Spain    29.0       Male                105.25
# 48      Italy    53.0     Female                235.50
# 49         UK    32.0       Male                140.25
# 50        USA    28.0     Female                180.00
# 52  Australia    39.0     Female                210.50
# 53      Japan    33.0       Male                145.75
# 54     Brazil    47.0     Female                195.25
# 57   Atlantis  1000.0  Merperson                500.00

# %%
#supprimer toutes les lignes qui apparaissent plus d’une fois dans les données
data_clean = data_filtered.drop_duplicates()
data_clean.shape
# Out:
# (52, 4)

# %%
colonnes_desees = ['Pays', 'Age', 'Genre', 'Dépenses des clients']
data_clean = data_clean[colonnes_desees]

# Enregistrer les données nettoyées dans un nouveau fichier CSV
data_clean.to_csv('data_nettoyees.csv', index=False)

# %%
df=pd.read_csv("data_nettoyees.csv")
df
# Out:
#          Pays     Age      Genre  Dépenses des clients
# 0      France    32.0     Female                150.50
# 1     Germany    45.0       Male                200.75
# 2       Spain    28.0     Female                 75.25
# 3       Italy    39.0       Male                180.00
# 4          UK    52.0     Female                250.30
# 5      France    22.0       Male                 90.00
# 6     Germany    36.0     Female                175.50
# 7       Spain    41.0       Male                120.75
# 8       Italy    29.0     Female                 95.25
# 9          UK    48.0       Male                220.00
# 10     France    35.0     Female                160.25
# 11    Germany    27.0       Male                 85.50
# 12      Spain    50.0     Female                190.75
# 13      Italy    33.0       Male                140.00
# 14         UK    44.0     Female                210.50
# 15     France    31.0       Male                130.25
# 16    Germany    38.0     Female                170.00
# 17      Italy    47.0     Female                200.25
# 18         UK    30.0       Male                110.50
# 19    Germany    29.0       Male                100.25
# 20      Spain    55.0     Female                230.00
# 21      Italy    36.0       Male                150.75
# 22         UK    25.0     Female                 80.50
# 23     France    49.0       Male                215.25
# 24    Germany    34.0     Female                145.00
# 25      Spain    40.0       Male                175.50
# 26      Italy    23.0     Female                 70.25
# 27         UK    51.0       Male                240.75
# 28     France    37.0     Female                165.00
# 29    Germany    43.0       Male                195.25
# 30      Spain    28.0     Female                 85.75
# 31      Italy    46.0       Male                205.50
# 32         UK    33.0     Female                135.25
# 33     France    30.0       Male                120.00
# 34    Germany    52.0     Female                225.75
# 35      Spain    35.0       Male                155.50
# 36      Italy    27.0     Female                 90.25
# 37         UK    48.0       Male                210.00
# 38     France    39.0     Female                170.25
# 39    Germany    31.0       Male                125.75
# 40      Spain    44.0     Female                190.00
# 41      Italy    25.0       Male                 75.50
# 42         UK    50.0     Female                220.25
# 43    Germany    41.0     Female                185.00
# 44      Spain    29.0       Male                105.25
# 45      Italy    53.0     Female                235.50
# 46         UK    32.0       Male                140.25
# 47        USA    28.0     Female                180.00
# 48  Australia    39.0     Female                210.50
# 49      Japan    33.0       Male                145.75
# 50     Brazil    47.0     Female                195.25
# 51   Atlantis  1000.0  Merperson                500.00
